# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # **Mr. Eangheng Phal** I would like to a data scientist.

# %% [markdown]
# # *I love to solve the problems.*
# # *People believe in data.*
# # *We have a lot of data, which is a good resource for data scientist.*

# %%
for i in range(3): 
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# # <This is my first code>

# %% [markdown]
# [Click here to go to Goole](https://www.google.com/)
# # <u>underline text</u>
# # <del>strike text<del>
# | A | B | C |
# | - | - | - |
# | 1 | 2 | 3 |
